# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %% [markdown]
# # Loading the dataset

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
# Out:
# C:\Users\sjitb\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %% [markdown]
# ## Checking the description of dataset

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
print(boston.data)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(boston.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
#  37.9 32.5 26.4 29.6 50.  32.  29.8 34.9 37.  30.5 36.4 31.1 29.1 50.
#  33.3 30.3 34.6 34.9 32.9 24.1 42.3 48.5 50.  22.6 24.4 22.5 24.4 20.
#  21.7 19.3 22.4 28.1 23.7 25.  23.3 28.7 21.5 23.  26.7 21.7 27.5 30.1
#  44.8 50.  37.6 31.6 46.7 31.5 24.3 31.7 41.7 48.3 29.  24.  25.1 31.5
#  23.7 23.3 22.  20.1 22.2 23.7 17.6 18.5 24.3 20.5 24.5 26.2 24.4 24.8
#  29.6 42.8 21.9 20.9 44.  50.  36.  30.1 33.8 43.1 48.8 31.  36.5 22.8
#  30.7 50.  43.5 20.7 21.1 25.2 24.4 35.2 32.4 32.  33.2 33.1 29.1 35.1
#  45.4 35.4 46.  50.  32.2 22.  20.1 23.2 22.3 24.8 28.5 37.3 27.9 23.9
#  21.7 28.6 27.1 20.3 22.5 29.  24.8 22.  26.4 33.1 36.1 28.4 33.4 28.2
#  22.8 20.3 16.1 22.1 19.4 21.6 23.8 16.2 17.8 19.8 23.1 21.  23.8 23.1
#  20.4 18.5 25.  24.6 23.  22.2 19.3 22.6 19.8 17.1 19.4 22.2 20.7 21.1
#  19.5 18.5 20.6 19.  18.7 32.7 16.5 23.9 31.2 17.5 17.2 23.1 24.5 26.6
#  22.9 24.1 18.6 30.1 18.2 20.6 17.8 21.7 22.7 22.6 25.  19.9 20.8 16.8
#  21.9 27.5 21.9 23.1 50.  50.  50.  50.  50.  13.8 13.8 15.  13.9 13.3
#  13.1 10.2 10.4 10.9 11.3 12.3  8.8  7.2 10.5  7.4 10.2 11.5 15.1 23.2
#   9.7 13.8 12.7 13.1 12.5  8.5  5.   6.3  5.6  7.2 12.1  8.3  8.5  5.
#  11.9 27.9 17.2 27.5 15.  17.2 17.9 16.3  7.   7.2  7.5 10.4  8.8  8.4
#  16.7 14.2 20.8 13.4 11.7  8.3 10.2 10.9 11.   9.5 14.5 14.1 16.1 14.3
#  11.7 13.4  9.6  8.7  8.4 12.8 10.5 17.1 18.4 15.4 10.8 11.8 14.9 12.6
#  14.1 13.  13.4 15.2 16.1 17.8 14.9 14.1 12.7 13.5 14.9 20.  16.4 17.7
#  19.5 20.2 21.4 19.9 19.  19.1 19.1 20.1 19.9 19.6 23.2 29.8 13.8 13.3
#  16.7 12.  14.6 21.4 23.  23.7 25.  21.8 20.6 21.2 19.1 20.6 15.2  7.
#   8.1 13.6 20.1 21.8 24.5 23.1 19.7 18.3 21.2 17.5 16.8 22.4 20.6 23.9
#  22.  11.9]

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# ## Preparing the Dataset

# %%
dataset = pd.DataFrame(boston.data,columns=boston.feature_names)
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
dataset['Price']=boston.target
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
dataset.isnull().sum() #### checking the missing values
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       Price
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# ### Exploratory Data Analysis

# %%
dataset_corr = pd.DataFrame(dataset.corr()) ### correlation between the features
dataset_corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# Price   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     Price
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# Price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
dataset_corr[dataset_corr>0.85] ### Checking for independent features which are higly correlated
# Out:
#          CRIM   ZN  INDUS  CHAS  NOX   RM  AGE  DIS       RAD       TAX  \
# CRIM      1.0  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# ZN        NaN  1.0    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# INDUS     NaN  NaN    1.0   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# CHAS      NaN  NaN    NaN   1.0  NaN  NaN  NaN  NaN       NaN       NaN
# NOX       NaN  NaN    NaN   NaN  1.0  NaN  NaN  NaN       NaN       NaN
# RM        NaN  NaN    NaN   NaN  NaN  1.0  NaN  NaN       NaN       NaN
# AGE       NaN  NaN    NaN   NaN  NaN  NaN  1.0  NaN       NaN       NaN
# DIS       NaN  NaN    NaN   NaN  NaN  NaN  NaN  1.0       NaN       NaN
# RAD       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  1.000000  0.910228
# TAX       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  0.910228  1.000000
# PTRATIO   NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# B         NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# LSTAT     NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# Price     NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
#
#          PTRATIO    B  LSTAT  Price
# CRIM         NaN  NaN    NaN    NaN
# ZN           NaN  NaN    NaN    NaN
# INDUS        NaN  NaN    NaN    NaN
# CHAS         NaN  NaN    NaN    NaN
# NOX          NaN  NaN    NaN    NaN
# RM           NaN  NaN    NaN    NaN
# AGE          NaN  NaN    NaN    NaN
# DIS          NaN  NaN    NaN    NaN
# RAD          NaN  NaN    NaN    NaN
# TAX          NaN  NaN    NaN    NaN
# PTRATIO      1.0  NaN    NaN    NaN
# B            NaN  1.0    NaN    NaN
# LSTAT        NaN  NaN    1.0    NaN
# Price        NaN  NaN    NaN    1.0

# %%
sns.scatterplot(dataset['TAX'], dataset['RAD'])
# Out:
# C:\Users\sjitb\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TAX', ylabel='RAD'>

# %%
dataset = dataset.drop(columns=['TAX'], axis=1) ### We choose to drop either 'RAD' or 'TAX' feature as these are highly correlated
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0     18.7
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0     18.7
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0     21.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0     21.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0     21.0
#
#           B  LSTAT  Price
# 0    396.90   4.98   24.0
# 1    396.90   9.14   21.6
# 2    392.83   4.03   34.7
# 3    394.63   2.94   33.4
# 4    396.90   5.33   36.2
# ..      ...    ...    ...
# 501  391.99   9.67   22.4
# 502  396.90   9.08   20.6
# 503  396.90   5.64   23.9
# 504  393.45   6.48   22.0
# 505  396.90   7.88   11.9
#
# [506 rows x 13 columns]

# %% [markdown]
# ### Independent dependent Features

# %%
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %% [markdown]
# ### Train Test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=43)

# %% [markdown]
# ### Standardizing the dataset

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,mean_absolute_error

# %%
def model_training(model,x,y):
    model.fit(x,y)
    y_predict_train = model.predict(x)
    print(f'For {model} ::')
    print(f'r2_score is {r2_score(y,y_predict_train)}')
    print(f'Mean squared error {mean_squared_error(y,y_predict_train)}')
    print(f'Root mean square error {np.sqrt(mean_squared_error(y,y_predict_train))}')
    print(f'Mean absolute error {mean_absolute_error(y,y_predict_train)}')
    print(model.get_params())
    print('\n')

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

models = [LinearRegression(),Ridge(),Lasso(),SVR(),RandomForestRegressor()]

# %%
for m in models:
    model_training(m,x_train, y_train)
# Out:
# For LinearRegression() ::
# r2_score is 0.7403500105732848
# Mean squared error 21.996115647847486
# Root mean square error 4.690001668213721
# Mean absolute error 3.3103349756446825
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': 'deprecated', 'positive': False}
#
#
# For Ridge() ::
# r2_score is 0.7403399466642933
# Mean squared error 21.996968206734692
# Root mean square error 4.690092558440045
# Mean absolute error 3.3046512414748075
# {'alpha': 1.0, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': 'deprecated', 'positive': False, 'random_state': None, 'solver': 'auto', 'tol': 0.001}
#
#
# For Lasso() ::
# r2_score is 0.6676663187003617
# Mean squared error 28.153477316450864
# Root mean square error 5.305985046760956
# Mean absolute error 3.6517860314636392
# {'alpha': 1.0, 'copy_X': True, 'fit_intercept': True, 'max_iter': 1000, 'normalize': 'deprecated', 'positive': False, 'precompute': False, 'random_state': None, 'selection': 'cyclic', 'tol': 0.0001, 'warm_start': False}
#
#
# For SVR() ::
# r2_score is 0.6423731902640271
# Mean squared error 30.296171715976364
# Root mean square error 5.504195828272861
# Mean absolute error 2.97039116721756
# {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#
#
# For RandomForestRegressor() ::
# r2_score is 0.9746337695661722
# Mean squared error 2.148887197740117
# Root mean square error 1.46590831832694
# Mean absolute error 0.8937118644067797
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
#  ## Using RandomForest Regression with default parameters on test Data to check for overfitting

# %%
random_forest = RandomForestRegressor()
random_forest.fit(x_train,y_train)

y_test_predict = random_forest.predict(x_test)

print('For test data using Random Forest')
print(f'r2_score is {r2_score(y_test,y_test_predict)}')
print(f'Mean squared error {mean_squared_error(y_test,y_test_predict)}')
print(f'Root mean square error {np.sqrt(mean_squared_error(y_test,y_test_predict))}')
print(f'Mean absolute error {mean_absolute_error(y_test,y_test_predict)}')
# Out:
# For test data using Random Forest
# r2_score is 0.878090223801711
# Mean squared error 10.035208749999995
# Root mean square error 3.1678397607833633
# Mean absolute error 2.3166184210526315

# %% [markdown]
# ## Above results show that the model is slighlty overfitting, hence we need to tweak the parameters

# %% [markdown]
# ## Using GridSearchcv to tweak paramters of RandomForest

# %%
parameters = {'n_estimators': [50,100,150,200,250,300,350,400,450,500,550],
              'max_depth': ['None',4,5,6,7,8,9,10],
              'bootstrap' :[True],
              'oob_score':[True,False], 
              'n_jobs' :[-1]}

# %%
from sklearn.model_selection import GridSearchCV
random_forest = RandomForestRegressor()
randomforrest_grid_search = GridSearchCV(estimator=random_forest,
                                        param_grid=parameters,
                                        scoring='neg_mean_squared_error',
                                        cv = 2,verbose = 2
                                        )

# %%
randomforrest_grid_search.fit(x_train,y_train)
# Out:
# Fitting 2 folds for each of 176 candidates, totalling 352 fits
# [CV] END bootstrap=True, max_depth=None, n_estimators=50, n_jobs=-1, oob_score=True; total time=   3.9s
# [CV] END bootstrap=True, max_depth=None, n_estimators=50, n_jobs=-1, oob_score=True; total time=   4.0s
# [CV] END bootstrap=True, max_depth=None, n_estimators=50, n_jobs=-1, oob_score=False; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, n_estimators=50, n_jobs=-1, oob_score=False; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, n_estimators=100, n_jobs=-1, oob_score=True; total time=   5.0s
# [CV] END bootstrap=True, max_depth=None, n_estimators=100, n_jobs=-1, oob_score=True; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, n_estimators=100, n_jobs=-1, oob_score=False; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=100, n_jobs=-1, oob_score=False; total time=   5.0s
# [CV] END bootstrap=True, max_depth=None, n_estimators=150, n_jobs=-1, oob_score=True; total time=   5.0s
# [CV] END bootstrap=True, max_depth=None, n_estimators=150, n_jobs=-1, oob_score=True; total time=   5.6s
# [CV] END bootstrap=True, max_depth=None, n_estimators=150, n_jobs=-1, oob_score=False; total time=   5.7s
# [CV] END bootstrap=True, max_depth=None, n_estimators=150, n_jobs=-1, oob_score=False; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, n_estimators=200, n_jobs=-1, oob_score=True; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, n_estimators=200, n_jobs=-1, oob_score=True; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=200, n_jobs=-1, oob_score=False; total time=   5.6s
# [CV] END bootstrap=True, max_depth=None, n_estimators=200, n_jobs=-1, oob_score=False; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, n_estimators=250, n_jobs=-1, oob_score=True; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, n_estimators=250, n_jobs=-1, oob_score=True; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=250, n_jobs=-1, oob_score=False; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=250, n_jobs=-1, oob_score=False; total time=   5.0s
# [CV] END bootstrap=True, max_depth=None, n_estimators=300, n_jobs=-1, oob_score=True; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=300, n_jobs=-1, oob_score=True; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=300, n_jobs=-1, oob_score=False; total time=   5.6s
# [CV] END bootstrap=True, max_depth=None, n_estimators=300, n_jobs=-1, oob_score=False; total time=   5.6s
# [CV] END bootstrap=True, max_depth=None, n_estimators=350, n_jobs=-1, oob_score=True; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=350, n_jobs=-1, oob_score=True; total time=   5.0s
# [CV] END bootstrap=True, max_depth=None, n_estimators=350, n_jobs=-1, oob_score=False; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=350, n_jobs=-1, oob_score=False; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=400, n_jobs=-1, oob_score=True; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, n_estimators=400, n_jobs=-1, oob_score=True; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=400, n_jobs=-1, oob_score=False; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, n_estimators=400, n_jobs=-1, oob_score=False; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=450, n_jobs=-1, oob_score=True; total time=   6.2s
# [CV] END bootstrap=True, max_depth=None, n_estimators=450, n_jobs=-1, oob_score=True; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=450, n_jobs=-1, oob_score=False; total time=   6.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=450, n_jobs=-1, oob_score=False; total time=   5.9s
# [CV] END bootstrap=True, max_depth=None, n_estimators=500, n_jobs=-1, oob_score=True; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, n_estimators=500, n_jobs=-1, oob_score=True; total time=   5.6s
# [CV] END bootstrap=True, max_depth=None, n_estimators=500, n_jobs=-1, oob_score=False; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, n_estimators=500, n_jobs=-1, oob_score=False; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, n_estimators=550, n_jobs=-1, oob_score=True; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, n_estimators=550, n_jobs=-1, oob_score=True; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, n_estimators=550, n_jobs=-1, oob_score=False; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, n_estimators=550, n_jobs=-1, oob_score=False; total time=   5.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=50, n_jobs=-1, oob_score=True; total time=   5.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=4, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=6, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=6, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=6, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=6, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=6, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.7s
# [CV] END bootstrap=True, max_depth=6, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.5s
# [CV] END bootstrap=True, max_depth=6, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=7, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=8, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=8, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=8, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.7s
# [CV] END bootstrap=True, max_depth=8, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=8, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, n_estimators=50, n_jobs=-1, oob_score=True; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, n_estimators=50, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=100, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, n_estimators=100, n_jobs=-1, oob_score=False; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=150, n_jobs=-1, oob_score=True; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=150, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, n_estimators=200, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=200, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, n_estimators=250, n_jobs=-1, oob_score=True; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=250, n_jobs=-1, oob_score=False; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=300, n_jobs=-1, oob_score=True; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, n_estimators=300, n_jobs=-1, oob_score=False; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=350, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=350, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=400, n_jobs=-1, oob_score=True; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=400, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, n_estimators=450, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=450, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, n_estimators=500, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=500, n_jobs=-1, oob_score=False; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, n_estimators=550, n_jobs=-1, oob_score=True; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, n_estimators=550, n_jobs=-1, oob_score=False; total time=   0.4s
# C:\Users\sjitb\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 44 fits failed out of a total of 352.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 44 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\sjitb\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 
id_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=50, n_jobs=-1, oob_score=True)

# %%
y_train_pred_grid_search = randomforrest_grid_search.predict(x_train)

# %%
print('For training data using GridSearchCV using Random Forest')
print(f'r2_score is {r2_score(y_train,y_train_pred_grid_search)}')
print(f'Mean squared error {mean_squared_error(y_train,y_train_pred_grid_search)}')
print(f'Root mean square error {np.sqrt(mean_squared_error(y_train,y_train_pred_grid_search))}')
print(f'Mean absolute error {mean_absolute_error(y_train,y_train_pred_grid_search)}')
# Out:
# For test data using GridSearchCV using Random Forest
# r2_score is 0.9596085629552752
# Mean squared error 3.4217398675045185
# Root mean square error 1.849794547376686
# Mean absolute error 1.3165512112010826

# %%
y_test_pred_grid_search = randomforrest_grid_search.predict(x_test)

# %%
print('For test data using GridSearchCV using Random Forest')
print(f'r2_score is {r2_score(y_test,y_test_pred_grid_search)}')
print(f'Mean squared error {mean_squared_error(y_test,y_test_pred_grid_search)}')
print(f'Root mean square error {np.sqrt(mean_squared_error(y_test,y_test_pred_grid_search))}')
print(f'Mean absolute error {mean_absolute_error(y_test,y_test_pred_grid_search)}')
# Out:
# For test data using GridSearchCV using Random Forest
# r2_score is 0.8743110378745871
# Mean squared error 10.346298810751685
# Root mean square error 3.216566307532255
# Mean absolute error 2.400023245357165

# %% [markdown]
# ## Pickle the Model file for deployement

# %%
import pickle
pickle.dump(randomforrest_grid_search,open('House_prediction.pkl','wb')) ### Saving the model as pickle file

# %%
pickled_model = pickle.load(open('House_prediction.pkl','rb')) ### Loading the trained pickle file mode

# %%
pickled_model.predict(scalar.transform(X))
# Out:
# array([29.26237198, 23.28306741, 34.66450139, 33.59782684, 35.34648407,
#        25.27608259, 20.71973097, 21.99612628, 17.04270489, 18.81056529,
#        16.50398561, 20.45320554, 19.79070468, 20.38933782, 19.33200102,
#        20.57223442, 21.32147826, 18.05152147, 19.18558788, 19.55685774,
#        14.88566148, 19.80615032, 15.36760433, 14.99248345, 16.22031639,
#        15.28225403, 17.51399963, 15.49484407, 19.85117397, 22.16712069,
#        14.79030212, 18.93876101, 14.72672143, 14.46418495, 14.0256716 ,
#        20.92691852, 19.97931048, 20.96287457, 20.64913403, 30.09801023,
#        34.69312481, 29.70871884, 24.05728188, 23.94965339, 21.17663029,
#        19.72653763, 20.35124078, 16.93234447, 15.9154743 , 18.83496855,
#        20.48298395, 21.62028961, 24.50347823, 21.12558783, 19.69070955,
#        33.20908986, 24.39338767, 30.53086278, 23.56179245, 20.77675879,
#        19.57070296, 17.75676885, 24.05968988, 25.42557718, 30.6324989 ,
#        24.67747111, 20.57235456, 20.61840103, 19.74093585, 20.74911986,
#        23.91748363, 20.45756146, 22.05045542, 23.80788862, 24.05183794,
#        23.32150904, 21.38112614, 21.5095011 , 21.81895022, 20.65027328,
#        27.37996702, 25.31345208, 23.82119834, 23.6093825 , 23.57808911,
#        26.42230577, 20.67337608, 21.97457483, 28.25586595, 29.88234523,
#        23.98529062, 24.00733608, 23.84706248, 24.22343596, 22.13340974,
#        27.28505259, 23.71304858, 41.89708333, 44.70232579, 33.85509726,
